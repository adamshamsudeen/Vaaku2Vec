# %%
from ulmfit import ULMFiT

# %%
model = ULMFiT("news/")

# %% [markdown]
# *Deshabhimani*

# %%
model.predict("ന്യൂസിലന്‍ഡിനെതിരായ ഒന്നാം ഏകദിനത്തില്‍ ഇന്ത്യയ്‌ക്ക്‌ എട്ട് വിക്കറ്റ് വിജയം. ന്യൂസിലൻഡ് 38 ഓവറിൽ 157 റൺസിനു പുറത്തായപ്പോൾ, 34.5 ഓവറില്‍ രണ്ടു വിക്കറ്റ് നഷ്ടത്തിൽ ഇന്ത്യ ലക്ഷ്യംകണ്ടു. ഇന്ത്യയ്‌ക്ക് വേണ്ടി ശിഖര്‍ ധവാന്‍ 74 റണ്‍സുമായി പുറത്താവാതെ നിന്നു. നേരത്തെ കുല്‍ദീപ് യാദവ്‌ നേടിയ നാല് വിക്കറ്റും മുഹമ്മദ് ഷമിയുടെ മൂന്ന് വിക്കറ്റ് പ്രകടനവുമാണ് ആതിഥേയരെ ചെറിയ സ്‌കോറില്‍ ഒതുക്കിയത്. 64 റണ്‍സെടുത്ത കെയ്ന്‍ വില്യംസണ്‍ മാത്രമാണ് കിവീസ് നിരയില്‍ ചെറുത്ത് നിന്നത്. നിര്‍ണായകമായ മൂന്ന് വിക്കറ്റ് നേടിയ മുഹമ്മദ് ഷമിയാണ് കളിയിലെ താരം.")
# Out:
# {'intent': {'confidence': 0.999926, 'name': 'Sports'},
#  'intent_ranking': [{'confidence': 7e-05, 'name': 'Kerala'},
#   {'confidence': 2e-06, 'name': 'Business'},
#   {'confidence': 2e-06, 'name': 'Gulf'},
#   {'confidence': 0.0, 'name': 'Entertainment'},
#   {'confidence': 0.0, 'name': 'India'}],
#  'processed_text': 'ന്യൂസിലന്ഡിനെതിരായ ഒന്നാം ഏകദിനത്തില് ഇന്ത്യയ്ക്ക് എട്ട് വിക്കറ്റ് വിജയം. ന്യൂസിലൻഡ് NUM ഓവറിൽ NUM റൺസിനു പുറത്തായപ്പോൾ, NUM ഓവറില് രണ്ടു വിക്കറ്റ് നഷ്ടത്തിൽ ഇന്ത്യ ലക്ഷ്യംകണ്ടു. ഇന്ത്യയ്ക്ക് വേണ്ടി ശിഖര് ധവാന് NUM റണ്സുമായി പുറത്താവാതെ നിന്നു. നേരത്തെ കുല്ദീപ് യാദവ് നേടിയ നാല് വിക്കറ്റും മുഹമ്മദ് ഷമിയുടെ മൂന്ന് വിക്കറ്റ് പ്രകടനവുമാണ് ആതിഥേയരെ ചെറിയ സ്കോറില് ഒതുക്കിയത്. NUM റണ്സെടുത്ത കെയ്ന് വില്യംസണ് മാത്രമാണ് കിവീസ് നിരയില് ചെറുത്ത് നിന്നത്. നിര്ണായകമായ മൂന്ന് വിക്കറ്റ് നേടിയ മുഹമ്മദ് ഷമിയാണ് കളിയിലെ താരം.'}

# %% [markdown]
# *Mathrubhumi*

# %%
model.predict("വേദനസംഹാരിയായും ഹൃദ്രോഗത്തിനും ഉപയോഗിക്കുന്ന ആസ്പിരിൻ അടങ്ങിയ മരുന്നായ ജസ്പിരിൻ (81 എം.ജി) നിരോധിച്ച് ഒമാൻ ആരോഗ്യ മന്ത്രാലയം ഉത്തരവിറക്കി. ആരോഗ്യമാനദ.")
# Out:
# {'intent': {'confidence': 0.99653, 'name': 'Gulf'},
#  'intent_ranking': [{'confidence': 0.001569, 'name': 'Business'},
#   {'confidence': 0.001341, 'name': 'Kerala'},
#   {'confidence': 0.000544, 'name': 'Entertainment'},
#   {'confidence': 9e-06, 'name': 'Sports'},
#   {'confidence': 8e-06, 'name': 'India'}],
#  'processed_text': 'വേദനസംഹാരിയായും ഹൃദ്രോഗത്തിനും ഉപയോഗിക്കുന്ന ആസ്പിരിൻ അടങ്ങിയ മരുന്നായ ജസ്പിരിൻ നിരോധിച്ച് ഒമാൻ ആരോഗ്യ മന്ത്രാലയം ഉത്തരവിറക്കി. ആരോഗ്യമാനദ.'}

# %%
model.predict("കാ​സ​ർ​കോ​ട്​: സം​സ്ഥാ​ന​ത്തെ വ്യാ​പാ​രി​ക​ൾ​ക്ക്​ ഇ​ത​ര​സം​സ്ഥാ​ന​ങ്ങ​ളി​ൽ​നി​ന്ന്​ ല​ഭി​ച്ച ​സി-​ഫോ​റം വ്യാ​ജ​മാ​ണെ​ന്ന​ നി​കു​തി​വ​കു​പ്പി​​െൻറ ക​ണ്ടെ​ത്ത​ലി​ൽ വ​ല​ഞ്ഞ്​ വ്യാ​പാ​രി​ക​ൾ. മി​ക്ക വ്യാ​പാ​രി​ക​ളും വ​ലി​യ തു​ക നി​കു​തി​കു​ടി​ശ്ശി​ക ഇ​ന​ത്തി​ൽ അ​ട​ക്കേ​ണ്ട ഗ​തി​കേ​ടി​ലാ​ണ്. ഒ​രു സം​സ്ഥാ​ന​ത്തു​നി​ന്ന്​ മ​റ്റൊ​രു സം​സ്ഥാ​ന​േ​ത്ത​ക്ക്​ ച​ര​ക്കു​ഗ​താ​ഗ​തം ന​ട​ത്തു​േ​മ്പാ​ൾ വ്യാ​പാ​രി​ക​ൾ​ക്ക്​ മൂ​ല്യ​വ​ർ​ധി​ത നി​കു​തി കു​റ​ഞ്ഞു​കി​ട്ടു​ന്ന​തി​ന്​ ച​ര​ക്ക്​ വാ​ങ്ങു​ന്ന സം​സ്ഥാ​ന​ത്തെ വ്യാ​പാ​രി​ക​ൾ സി-​ഫോ​റം ന​ൽ​കും. ഇ​ത്ത​ര​ത്തി​ൽ സി-​ഫോ​റം ല​ഭി​ക്കു​ന്ന വ്യാ​പാ​രി​ക​ൾ അ​ഞ്ചു ശ​ത​മാ​നം നി​കു​തി അ​ട​ക്കു​ന്ന​തി​ന്​ പ​ക​രം ര​ണ്ടു​ ശ​ത​മാ​നം അ​ട​ച്ചാ​ൽ മ​തി. നി​കു​തി​യി​ള​വ്​ ല​ഭി​ക്കു​ന്ന​തി​നാ​യി വ്യാ​പാ​രി​ക​ൾ സ​മ​ർ​പ്പി​ച്ച സി-​ഫോ​റം വ്യാ​ജ​മാ​ണെ​ന്ന്​ നി​കു​തി​വ​കു​പ്പ്​ ക​ണ്ടെ​ത്തി​യ​തോ​ടെ​യാ​ണ്​ വ​ലി​യ തു​ക​യു​ടെ സാ​മ്പ​ത്തി​ക​ബാ​ധ്യ​ത കൊ​ടു​ത്തു​തീ​ർ​ക്കേ​ണ്ട അ​വ​സ്ഥ വ്യാ​പാ​രി​ക​ൾ​ക്ക്​ വ​ന്നു​ചേ​ർ​ന്ന​ത്. ")
# Out:
# {'intent': {'confidence': 0.99228, 'name': 'Kerala'},
#  'intent_ranking': [{'confidence': 0.003653, 'name': 'Business'},
#   {'confidence': 0.003234, 'name': 'India'},
#   {'confidence': 0.000736, 'name': 'Gulf'},
#   {'confidence': 8.5e-05, 'name': 'Entertainment'},
#   {'confidence': 1.2e-05, 'name': 'Sports'}],
# ...

# %% [markdown]
# *Madhayamam* - this news was actually present under Business.

# %%
model.predict("മും​ബൈ: ഒ​റ്റ ദി​വ​സം 1,007 വി​മാ​ന സ​ർ​വി​സു​ക​ൾ ന​ട​ത്തി സ്വ​ന്തം റെ​ക്കോ​ഡ്​ പ​ഴ​ങ്ക​ഥ​യാ​ക്കി മും​ബൈ ഛത്ര​പ​തി ശി​വാ​ജി മ​ഹാ​രാ​ജ്​ രാ​ജ്യാ​ന്ത​ര വി​മാ​ന​ത്താ​വ​ളം.&nbsp;രാ​ജ​സ്​​ഥാ​നി​ലെ ഉ​ദ​യ്​​പു​രി​ൽ അം​ബാ​നി പു​ത്രി​യു​ടെ വി​വാ​ഹ​ത്തി​ന്​ എ​ത്തി​യ​വ​രു​ടെ വി​മാ​ന​ങ്ങ​ൾ​കൂ​ടി വ​ൻ​തോ​തി​ൽ എ​ത്തി​യ​താ​ണ്​ മും​ബൈ​ക്ക്​ പു​തി​യ റെ​ക്കോ​ഡ്​ സ​മ്മാ​നി​ച്ച​ത്.")
# Out:
# {'intent': {'confidence': 0.785693, 'name': 'Sports'},
#  'intent_ranking': [{'confidence': 0.12, 'name': 'Business'},
#   {'confidence': 0.057228, 'name': 'India'},
#   {'confidence': 0.029786, 'name': 'Entertainment'},
#   {'confidence': 0.00553, 'name': 'Gulf'},
#   {'confidence': 0.001763, 'name': 'Kerala'}],
#  'processed_text': 'മുംബൈ: ഒറ്റ ദിവസം NUM വിമാന സർവിസുകൾ നടത്തി സ്വന്തം റെക്കോഡ് പഴങ്കഥയാക്കി മുംബൈ ഛത്രപതി ശിവാജി മഹാരാജ് രാജ്യാന്തര വിമാനത്താവളം.& രാജസ്ഥാനിലെ ഉദയ്പുരിൽ അംബാനി പുത്രിയുടെ വിവാഹത്തിന് എത്തിയവരുടെ വിമാനങ്ങൾകൂടി വൻതോതിൽ എത്തിയതാണ് മുംബൈക്ക് പുതിയ റെക്കോഡ് സമ്മാനിച്ചത്.'}
